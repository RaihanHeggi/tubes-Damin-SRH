# %% [markdown]
# TUGAS BESAR DATA MINING
#
# NAMA : SYA RAIHAN HEGGI
#
# NIM : 1301184219
#
# KELAS : IF-41-GAB01

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sn
import numpy as np

# %%
df_train = pd.read_csv("train.csv", sep="|")
df_test = pd.read_csv("test.csv",sep="|")

# %%
df_train.head()
# Out:
#    trustLevel  totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 0           5                    1054       54.70              7
# 1           3                     108       27.36              5
# 2           3                    1516       62.16              3
# 3           6                    1791       92.31              8
# 4           5                     430       81.53              3
#
#    scansWithoutRegistration  quantityModifications  scannedLineItemsPerSecond  \
# 0                         0                      3                   0.027514
# 1                         2                      4                   0.129630
# 2                        10                      5                   0.008575
# 3                         4                      4                   0.016192
# 4                         7                      2                   0.062791
#
#    valuePerSecond  lineItemVoidsPerPosition  fraud
# 0        0.051898                  0.241379      0
# ...

# %%
df_test.head()
# Out:
#    trustLevel  totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 0           4                     467       88.48              4
# 1           3                    1004       58.99              7
# 2           1                     162       14.00              4
# 3           5                     532       84.79              9
# 4           5                     890       42.16              4
#
#    scansWithoutRegistration  quantityModifications  scannedLineItemsPerSecond  \
# 0                         8                      4                   0.014989
# 1                         6                      1                   0.026892
# 2                         5                      4                   0.006173
# 3                         3                      4                   0.026316
# 4                         0                      0                   0.021348
#
#    valuePerSecond  lineItemVoidsPerPosition
# 0        0.189465                  0.571429
# ...

# %% [markdown]
# # SHAPE DATASET

# %%
df_train.shape
# Out:
# (1879, 10)

# %%
df_test.shape
# Out:
# (498121, 9)

# %% [markdown]
# # INFORMASI DATASET

# %%
df_train.dtypes
# Out:
# trustLevel                     int64
# totalScanTimeInSeconds         int64
# grandTotal                   float64
# lineItemVoids                  int64
# scansWithoutRegistration       int64
# quantityModifications          int64
# scannedLineItemsPerSecond    float64
# valuePerSecond               float64
# lineItemVoidsPerPosition     float64
# fraud                          int64
# dtype: object

# %%
df_test.dtypes
# Out:
# trustLevel                     int64
# totalScanTimeInSeconds         int64
# grandTotal                   float64
# lineItemVoids                  int64
# scansWithoutRegistration       int64
# quantityModifications          int64
# scannedLineItemsPerSecond    float64
# valuePerSecond               float64
# lineItemVoidsPerPosition     float64
# dtype: object

# %% [markdown]
# # CHECK MISSING dan DUPLICATE VALUE

# %% [markdown]
# Cek Missing Value

# %%
df_train.isnull().sum()
# Out:
# trustLevel                   0
# totalScanTimeInSeconds       0
# grandTotal                   0
# lineItemVoids                0
# scansWithoutRegistration     0
# quantityModifications        0
# scannedLineItemsPerSecond    0
# valuePerSecond               0
# lineItemVoidsPerPosition     0
# fraud                        0
# dtype: int64

# %%
df_test.isnull().sum()
# Out:
# trustLevel                   0
# totalScanTimeInSeconds       0
# grandTotal                   0
# lineItemVoids                0
# scansWithoutRegistration     0
# quantityModifications        0
# scannedLineItemsPerSecond    0
# valuePerSecond               0
# lineItemVoidsPerPosition     0
# dtype: int64

# %% [markdown]
# Cek Duplicate

# %%
df_train.duplicated().sum()
# Out:
# 0

# %%
df_train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Check Value dari Dataset

# %% [markdown]
# ## Data Train

# %%
df_train.describe()
# Out:
#         trustLevel  totalScanTimeInSeconds   grandTotal  lineItemVoids  \
# count  1879.000000             1879.000000  1879.000000    1879.000000
# mean      3.401809              932.153273    50.864492       5.469931
# std       1.709404              530.144640    28.940202       3.451169
# min       1.000000                2.000000     0.010000       0.000000
# 25%       2.000000              474.500000    25.965000       2.000000
# 50%       3.000000              932.000000    51.210000       5.000000
# 75%       5.000000             1397.000000    77.285000       8.000000
# max       6.000000             1831.000000    99.960000      11.000000
#
#        scansWithoutRegistration  quantityModifications  \
# count               1879.000000            1879.000000
# mean                   4.904204               2.525279
# std                    3.139697               1.695472
# min                    0.000000               0.000000
# ...

# %%
grafikValue = df_train.hist(figsize = (10,10))

# %% [markdown]
# Dari melihat grafik ini bisa dilihat tidak ada persebaran yang nilainya wrong sehingga dapat dilanjutkan ke eksplorasi berikutnya

# %%
df_train.corr()
# Out:
#                            trustLevel  totalScanTimeInSeconds  grandTotal  \
# trustLevel                   1.000000                0.025264    0.047656
# totalScanTimeInSeconds       0.025264                1.000000   -0.001230
# grandTotal                   0.047656               -0.001230    1.000000
# lineItemVoids               -0.017312                0.019068    0.006321
# scansWithoutRegistration     0.017296                0.009066   -0.030573
# quantityModifications        0.006506               -0.011415   -0.008163
# scannedLineItemsPerSecond    0.030701               -0.262988   -0.011885
# valuePerSecond               0.027626               -0.208450    0.075679
# lineItemVoidsPerPosition     0.009241               -0.011623   -0.008858
# fraud                       -0.319765                0.110414    0.001421
#
#                            lineItemVoids  scansWithoutRegistration  \
# trustLevel                     -0.017312                  0.017296
# ...

# %% [markdown]
# Dari heatmap kemungkinan feature yang dapat digunakan untuk membangun adalah ** totalScanTimeInSeconds, grandTotal, lineItemVoids, scansWithoutRegistration **

# %%
df_train.cov()
# Out:
#                            trustLevel  totalScanTimeInSeconds  grandTotal  \
# trustLevel                   2.922063               22.895250    2.357545
# totalScanTimeInSeconds      22.895250           281053.339647  -18.870098
# grandTotal                   2.357545              -18.870098  837.535273
# lineItemVoids               -0.102129               34.886933    0.631323
# scansWithoutRegistration     0.092825               15.090303   -2.777977
# quantityModifications        0.018857              -10.260000   -0.400524
# scannedLineItemsPerSecond    0.014617              -38.830588   -0.095794
# valuePerSecond               0.058659             -137.266463    2.720485
# lineItemVoidsPerPosition     0.020966               -8.178233   -0.340256
# fraud                       -0.125020               13.388211    0.009405
#
#                            lineItemVoids  scansWithoutRegistration  \
# trustLevel                     -0.102129                  0.092825
# ...

# %%
df_train.var()
# Out:
# trustLevel                        2.922063
# totalScanTimeInSeconds       281053.339647
# grandTotal                      837.535273
# lineItemVoids                    11.910570
# scansWithoutRegistration          9.857698
# quantityModifications             2.874627
# scannedLineItemsPerSecond         0.077569
# valuePerSecond                    1.542898
# lineItemVoidsPerPosition          1.761570
# fraud                             0.052313
# dtype: float64

# %% [markdown]
# ## Data Test

# %%
df_test.describe()
# Out:
#           trustLevel  totalScanTimeInSeconds     grandTotal  lineItemVoids  \
# count  498121.000000           498121.000000  498121.000000  498121.000000
# mean        3.503257              915.608772      49.988990       5.495926
# std         1.707662              528.772880      28.873426       3.447683
# min         1.000000                1.000000       0.000000       0.000000
# 25%         2.000000              458.000000      24.930000       3.000000
# 50%         4.000000              916.000000      50.030000       5.000000
# 75%         5.000000             1374.000000      75.020000       8.000000
# max         6.000000             1831.000000      99.990000      11.000000
#
#        scansWithoutRegistration  quantityModifications  \
# count             498121.000000          498121.000000
# mean                   5.001281               2.499015
# std                    3.163795               1.708182
# min                    0.000000               0.000000
# ...

# %%
grafikValue = df_test.hist(figsize = (10,10))

# %%
df_test.corr()
# Out:
#                            trustLevel  totalScanTimeInSeconds  grandTotal  \
# trustLevel                   1.000000                0.000065   -0.000718
# totalScanTimeInSeconds       0.000065                1.000000   -0.001570
# grandTotal                  -0.000718               -0.001570    1.000000
# lineItemVoids               -0.000436               -0.000619    0.000872
# scansWithoutRegistration     0.000518               -0.000886    0.001876
# quantityModifications       -0.000806               -0.000602    0.000314
# scannedLineItemsPerSecond   -0.000567               -0.169937    0.000578
# valuePerSecond               0.000391               -0.168923    0.075609
# lineItemVoidsPerPosition     0.000469               -0.000038   -0.000773
#
#                            lineItemVoids  scansWithoutRegistration  \
# trustLevel                     -0.000436                  0.000518
# totalScanTimeInSeconds         -0.000619                 -0.000886
# ...

# %%
df_test.cov()
# Out:
#                            trustLevel  totalScanTimeInSeconds  grandTotal  \
# trustLevel                   2.916111                0.058743   -0.035417
# totalScanTimeInSeconds       0.058743           279600.758321  -23.965762
# grandTotal                  -0.035417              -23.965762  833.674702
# lineItemVoids               -0.002566               -1.128165    0.086814
# scansWithoutRegistration     0.002798               -1.482423    0.171393
# quantityModifications       -0.002352               -0.544137    0.015496
# scannedLineItemsPerSecond   -0.000504              -46.824301    0.008692
# valuePerSecond               0.001148             -153.443034    3.750269
# lineItemVoidsPerPosition     0.001057               -0.026711   -0.029481
#
#                            lineItemVoids  scansWithoutRegistration  \
# trustLevel                     -0.002566                  0.002798
# totalScanTimeInSeconds         -1.128165                 -1.482423
# ...

# %%
df_test.var()
# Out:
# trustLevel                        2.916111
# totalScanTimeInSeconds       279600.758321
# grandTotal                      833.674702
# lineItemVoids                    11.886521
# scansWithoutRegistration         10.009598
# quantityModifications             2.917887
# scannedLineItemsPerSecond         0.271537
# valuePerSecond                    2.951065
# lineItemVoidsPerPosition          1.743020
# dtype: float64

# %% [markdown]
# ## LIHAT OUTLIER

# %%
ax = sn.boxplot(x=df_train['trustLevel'])

# %%
ax = sn.boxplot(x=df_train['totalScanTimeInSeconds'])

# %%
ax = sn.boxplot(x=df_train['grandTotal'])

# %%
ax = sn.boxplot(x=df_train['lineItemVoids'])

# %%
ax = sn.boxplot(x=df_train['scansWithoutRegistration'])

# %%
ax = sn.boxplot(x=df_train['quantityModifications'])

# %%
ax = sn.boxplot(x=df_train['scannedLineItemsPerSecond'])

# %%
ax = sn.boxplot(x=df_train['valuePerSecond'])

# %%
ax = sn.boxplot(x=df_train['lineItemVoidsPerPosition'])

# %% [markdown]
# # DISTRIBUTION VALUE 3 VARIABLE

# %%
df = df_train[['scannedLineItemsPerSecond','valuePerSecond','lineItemVoidsPerPosition']]

# %%
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sn.distplot(df['scannedLineItemsPerSecond'])
plt.subplot(1,3,2)
sn.distplot(df['valuePerSecond'])
plt.subplot(1,3,3)
sn.distplot(df['lineItemVoidsPerPosition'])
plt.show()

# %%
df_train.skew()
# Out:
# trustLevel                    0.087738
# totalScanTimeInSeconds       -0.033743
# grandTotal                   -0.027450
# lineItemVoids                 0.011823
# scansWithoutRegistration      0.056318
# quantityModifications        -0.031998
# scannedLineItemsPerSecond    15.078211
# valuePerSecond               20.771462
# lineItemVoidsPerPosition      4.315624
# fraud                         3.892311
# dtype: float64

# %% [markdown]
# # CEK ANOMALY OUTLIER DENGAN SVM

# %%
from sklearn.svm import OneClassSVM

# %%
svm_model = OneClassSVM(kernel = 'rbf', gamma = 0.001, nu = 0.03).fit(df)

# %%
svm_prediction = svm_model.predict(df)

# %%
outlier_index = np.where(svm_prediction == -1) 
outlier_values = df.iloc[outlier_index]

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
plt.title("scannedLineItems vs valuePerSecond")
plt.xlabel("scannedLineItemsPerSecond")
plt.ylabel("valuePerSecond")
plt.scatter(df["scannedLineItemsPerSecond"], df["valuePerSecond"])
plt.scatter(outlier_values["scannedLineItemsPerSecond"], outlier_values["valuePerSecond"], c = "r")
plt.subplot(1,3,2)
plt.title("scannedLineItems vs lineItemVoidsPerPosition")
plt.scatter(df["scannedLineItemsPerSecond"], df["lineItemVoidsPerPosition"])
plt.scatter(outlier_values["scannedLineItemsPerSecond"], outlier_values["lineItemVoidsPerPosition"], c = "r")
plt.subplot(1,3,3)
plt.title("valuePerSecond vs lineItemVoidsPerPosition")
plt.scatter(df["valuePerSecond"], df["lineItemVoidsPerPosition"])
plt.scatter(outlier_values["valuePerSecond"], outlier_values["lineItemVoidsPerPosition"], c = "r")

# %% [markdown]
# # CLEANING OUTLIER

# %%
ax = sn.boxplot(x=df_train['scannedLineItemsPerSecond'])

# %%
Quartile_Bawah = np.percentile(df_train['scannedLineItemsPerSecond'],25)
Quartile_Atas = np.percentile(df_train['scannedLineItemsPerSecond'],75)
IQR = Quartile_Atas-Quartile_Bawah
Upper = Quartile_Atas+1.5*IQR
Lower = Quartile_Bawah+1.5*IQR
Upper,Lower
# Out:
# (0.06890935645513056, 0.04469910954942052)

# %%
warnings.filterwarnings('ignore')
indexUpper= df_train[(df_train['scannedLineItemsPerSecond'] > df_train['scannedLineItemsPerSecond'].quantile(0.75))].index
indexLower= df_train[(df_train['scannedLineItemsPerSecond'] < df_train['scannedLineItemsPerSecond'].quantile(0.25))].index
df_train.drop(indexUpper, inplace=True)
df_train.drop(indexLower, inplace=True)
plt.boxplot(df_train['scannedLineItemsPerSecond'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20f2882d4c8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20f2882ddc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20f2882aa88>],
#  'medians': [<matplotlib.lines.Line2D at 0x20f28833d48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20f28837bc8>],
#  'means': []}

# %%
ax = sn.boxplot(x=df_train['valuePerSecond'])

# %%
Quartile_Bawah = np.percentile(df_train['valuePerSecond'],25)
Quartile_Atas = np.percentile(df_train['valuePerSecond'],75)
IQR = Quartile_Atas-Quartile_Bawah
Upper = Quartile_Atas+1.5*IQR
Lower = Quartile_Bawah+1.5*IQR
Upper,Lower
# Out:
# (0.15063224409138967, 0.10030537048840342)

# %%
warnings.filterwarnings('ignore')
indexUpper= df_train[(df_train['valuePerSecond'] > df_train['valuePerSecond'].quantile(0.75))].index
indexLower= df_train[(df_train['valuePerSecond'] < df_train['valuePerSecond'].quantile(0.25))].index
df_train.drop(indexUpper, inplace=True)
df_train.drop(indexLower, inplace=True)
plt.boxplot(df_train['valuePerSecond'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20f288fe248>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20f288feb48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20f288fb808>],
#  'medians': [<matplotlib.lines.Line2D at 0x20f28903ac8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20f28907948>],
#  'means': []}

# %%
ax = sn.boxplot(x=df_train['lineItemVoidsPerPosition'])

# %%
Quartile_Bawah = np.percentile(df_train['lineItemVoidsPerPosition'],25)
Quartile_Atas = np.percentile(df_train['lineItemVoidsPerPosition'],75)
IQR = Quartile_Atas-Quartile_Bawah
Upper = Quartile_Atas+1.5*IQR
Lower = Quartile_Bawah+1.5*IQR
Upper,Lower
# Out:
# (0.9363636363636381, 0.6151515151515161)

# %%
warnings.filterwarnings('ignore')
indexUpper= df_train[(df_train['lineItemVoidsPerPosition'] > df_train['lineItemVoidsPerPosition'].quantile(0.75))].index
indexLower= df_train[(df_train['lineItemVoidsPerPosition'] < df_train['lineItemVoidsPerPosition'].quantile(0.25))].index
df_train.drop(indexUpper, inplace=True)
df_train.drop(indexLower, inplace=True)
plt.boxplot(df_train['lineItemVoidsPerPosition'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20f28b39b48>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20f28b3fb48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20f28b39148>],
#  'medians': [<matplotlib.lines.Line2D at 0x20f28b42ac8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20f28b42bc8>],
#  'means': []}

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
plt.title("scannedLineItemsPerSecond")
plt.boxplot(df_train['scannedLineItemsPerSecond'])
plt.subplot(1,3,2)
plt.title("valuePerSecond")
plt.boxplot(df_train['valuePerSecond'])
plt.subplot(1,3,3)
plt.title("lineItemVoidsPerPosition")
plt.boxplot(df_train['lineItemVoidsPerPosition'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20f28c3aec8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20f28c3ef88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20f28c3a348>],
#  'medians': [<matplotlib.lines.Line2D at 0x20f28c43fc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20f28c48988>],
#  'means': []}

# %%
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(16,5))
plt.subplot(1,3,1)
sn.distplot(df_train['scannedLineItemsPerSecond'])
plt.subplot(1,3,2)
sn.distplot(df_train['valuePerSecond'])
plt.subplot(1,3,3)
sn.distplot(df_train['lineItemVoidsPerPosition'])
plt.show()

# %%
df_train.skew()
# Out:
# trustLevel                  -0.055284
# totalScanTimeInSeconds      -0.457393
# grandTotal                  -0.060956
# lineItemVoids                0.218349
# scansWithoutRegistration     0.157187
# quantityModifications        0.039724
# scannedLineItemsPerSecond    0.584444
# valuePerSecond               0.051412
# lineItemVoidsPerPosition     0.166074
# fraud                        2.536249
# dtype: float64

# %% [markdown]
# ## Cek Menggunakan Heatmap

# %%
corrVal = df_train.corr()

# %%
plt.figure(figsize=(10,10))
sn.heatmap(corrVal,annot=True,cmap ='RdYlGn')
plt.show()

# %% [markdown]
# dari heatmap kita bisa melihat bahwa kemungkinan line yang akan digunakan adalah ** lineItemVoids, totalScanTimeInSeconds, grandTotal , lineItemVoidsPerPosition, scannedLineItemsPerSecond **

# %% [markdown]
# ## Cek Menggunakan Feature Importance

# %%
from sklearn.ensemble import ExtraTreesClassifier
model= ExtraTreesClassifier()
X = df_train[df_train.columns[:9]]
Y = df_train['fraud']
model.fit(X,Y)
importance = pd.Series(model.feature_importances_,index=X.columns).sort_values(ascending=False)
importance.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# dari heatmap kita bisa melihat bahwa kemungkinan line yang akan digunakan adalah ** trustLevel, lineItemVoids, totalScanTimeInSeconds, grandTotal , scannedLineItemsPerSecond **

# %% [markdown]
# ## Cek Menggunakan Univarite Selection

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
bestfeatures = SelectKBest(score_func=chi2, k=9)
fit = bestfeatures.fit(X,Y)
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Feature','Score']
print(featureScores.nlargest(10,'Score'))
# Out:
#                      Feature       Score
# 1     totalScanTimeInSeconds  921.331002
# 0                 trustLevel   41.718712
# 3              lineItemVoids   11.535654
# 2                 grandTotal   10.224953
# 4   scansWithoutRegistration    0.241275
# 8   lineItemVoidsPerPosition    0.014016
# 7             valuePerSecond    0.008598
# 5      quantityModifications    0.002135
# 6  scannedLineItemsPerSecond    0.000452

# %% [markdown]
# dari heatmap kita bisa melihat bahwa kemungkinan line yang akan digunakan adalah ** trustLevel, lineItemVoids, totalScanTimeInSeconds, grandTotal**

# %% [markdown]
# # NORMALISASI

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
normalize = MinMaxScaler()
d = normalize.fit_transform(df_train[df_train.columns[:9]])
scaled_df = pd.DataFrame(d, columns=['trustLevel', 'scannedLineItemsPerSecond','totalScanTimeInSeconds',"quantityModifications","scansWithoutRegistration","lineItemVoids","grandTotal","valuePerSecond","lineItemVoidsPerPosition"])
scaled_df.head()
# Out:
#    trustLevel  scannedLineItemsPerSecond  totalScanTimeInSeconds  \
# 0         0.8                   0.491481                0.488703
# 1         0.4                   0.794233                0.574263
# 2         1.0                   0.974443                0.920060
# 3         1.0                   0.431193                0.611882
# 4         0.8                   0.805374                0.833123
#
#    quantityModifications  scansWithoutRegistration  lineItemVoids  grandTotal  \
# 0                    0.6                       0.0            0.6    0.803674
# 1                    0.2                       1.0            1.0    0.006958
# 2                    0.7                       0.4            0.8    0.327380
# 3                    0.6                       0.0            0.4    0.826908
# 4                    0.3                       0.2            0.8    0.085282
#
#    valuePerSecond  lineItemVoidsPerPosition
# 0        0.538814                  0.336370
# ...

# %% [markdown]
# # SIMPAN DATA

# %%
df_final = scaled_df
df_final["fraud"] = df_train["fraud"].values
df_final
# Out:
#      trustLevel  scannedLineItemsPerSecond  totalScanTimeInSeconds  \
# 0           0.8                   0.491481                0.488703
# 1           0.4                   0.794233                0.574263
# 2           1.0                   0.974443                0.920060
# 3           1.0                   0.431193                0.611882
# 4           0.8                   0.805374                0.833123
# ..          ...                        ...                     ...
# 235         0.8                   0.754260                0.899644
# 236         0.0                   0.760813                0.537447
# 237         0.6                   0.443644                0.277211
# 238         0.8                   0.321101                0.204381
# 239         0.2                   0.303408                0.445693
#
#      quantityModifications  scansWithoutRegistration  lineItemVoids  \
# 0                      0.6                       0.0            0.6
# ...

# %%
df_final.to_csv("processed_train.csv")
